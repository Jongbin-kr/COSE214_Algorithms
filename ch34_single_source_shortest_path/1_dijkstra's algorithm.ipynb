# %% [markdown]
# (교재 24.3장)
#
# Dijkstra's algorithm을 구현하여, source node A에서부터 다른 노드 (A포함)로 가는 최소 방문 cost를 모두 출력하는 코드를 작성하시오.
#
# *주의사항
#
# 1. Python으로 작성하는 경우, 인풋 첫번째 줄처럼 숫자가 아닌 string을 입력받기 위해서는 raw_input 사용
#
# 2. Min-priority queue는 직접 구현하여 사용 (단, DECREASE-KEY operation에 유의)
#
# ------
#
# INPUT
#
# Line 0: names of vertices, separated by comma  ex) A,B,C,D,E,F,G (sorted alphabetically)
#
# Line 1: the number of edges n
#
# Line 2~(n+1): one edge per line, edge = (vertex_from,vertex_to,weight)
#
#
# ---------
#
# OUTPUT
#
#
# Line 0: shortest path distance from A to A
#
# Line 1: shortest path distance from A to B
#
# Line 2: shortest path distance from A to C
#
# ...
#
#
# ------
#
# SAMPLE INPUT
#
#
# A,B,C,D,E
#
# 10
#
# A,B,10
#
# A,C,5
#
# B,C,2
#
# B,D,1
#
# C,B,3
#
# C,D,9
#
# C,E,2
#
# D,E,4
#
# E,A,7
#
# E,D,6
#
#
#
# ---------
# SAMPLE OUTPUT
#
#
# 0
#
# 8
#
# 5
#
# 9
#
# 7

# %%
## graph node with distance and predecessor
class Graph_node():
    
    def __init__(self, vertex_name):
        self.vertex_name = vertex_name
        self.edge_dict = {} ## dest: dist
        self.pred = '' ## predecessor vertex name for min_distance
        self.min_dist = 0

# %%
## min-priority que 

class Min_heap():
    def __init__(self, graph_node_list):
        self.arr = graph_node_list
        self.heap_size = len(self.arr) -1 ## -1 because index 0 in node list is 'X'. we don't use the zero-index value.

    def return_build_min_heap(self):
        for i in range(1, (self.heap_size//2)+1)[::-1]:
            self.min_heapify(i)
        return self
    
    def min_heapify(self, i):
        smallest = i
        l = (2 * i)
        r = (2 * i) + 1
        
        if l < self.heap_size and self.arr[l].min_dist < self.arr[i].min_dist:
            smallest = l
        
        if r <= self.heap_size and self.arr[r].min_dist < self.arr[smallest].min_dist:
            smallest = r
        
        if smallest != i:
            self.arr[i], self.arr[smallest] = self.arr[smallest], self.arr[i] ## swapping
            self.min_heapify(smallest)
            
                  
class Min_priority_que(Min_heap):

    def return_min_heap_extract(self):       
        min_node = self.arr[1]
        self.arr[1] = self.arr[self.heap_size] ## input the largest node into first index to min heapify
        self.heap_size -= 1
        self.min_heapify(1)
        return min_node

# %%
# ####################################################
# ## !!!! modify following commented code for activate this code for submit
# ####################################################

## input graph nodes' name, create graph nodes and append them into graph node list
input_vertex_name_list = input().split(',')
graph_node_list = ['X'] ## we don't use index number 0.
for vertex_name in input_vertex_name_list:
    new_node = Graph_node(vertex_name)
    graph_node_list.append(new_node)

## input how many edges, update edge info to the source graph node
input_how_many_edges = int(input())
    
## !! EDIT THIS CODE before SUBMITTING      ## !!
# for i in range(input_how_many_edges):     ## !! maybe need to indentation following code
input_edge_list = input().split()           ## !!
                                            ## !!
for input_edge in input_edge_list:          ## !!
    src, dest, dist = input_edge.split(',') ## !!
## !! EDIT THIS CODE before SUBMITTING      ## !!

    for i in range(1, len(graph_node_list)):
        if src == graph_node_list[i].vertex_name:
            graph_node_list[i].edge_dict[dest] = int(dist)

# %%
## utiliy

def print_graph(iterable):
    print(iterable)

    if type(iterable) != set:
        if type(iterable[0]) == str:
            iterable = iterable[1:]
    
    for x in iterable:
        print(
            x.vertex_name,
            x.min_dist,
            x.pred,
            x.edge_dict
        )

# %%
print_graph(graph_node_list)
# Out:
# ['X', <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# A 0  {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# B 0  {'A': 2, 'E': 5, 'H': 7}
# C 0  {'H': 1}
# D 0  {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
# E 0  {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# F 0  {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# G 0  {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# H 0  {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 0  {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 0  {'D': 7, 'H': 1}

# %%
## initialize
for graph_node in graph_node_list[1:]:
    graph_node.min_dist = float("inf")
    graph_node.pred = 'NIL'
graph_node_list[1].min_dist = 0 ## we just follow the vertex name input order. Therefore, source node is the first node.

# %%
print_graph(graph_node_list)
# Out:
# ['X', <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# B inf NIL {'A': 2, 'E': 5, 'H': 7}
# C inf NIL {'H': 1}
# D inf NIL {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
# E inf NIL {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# F inf NIL {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# G inf NIL {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# H inf NIL {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J inf NIL {'D': 7, 'H': 1}

# %%
## let's build min-que with node_list
h = Min_priority_que(graph_node_list)
print(h.arr)
q = h.return_build_min_heap()
print(q.arr)
# Out:
# ['X', <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# ['X', <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]

# %%
print_graph(graph_node_list)
# Out:
# ['X', <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# B inf NIL {'A': 2, 'E': 5, 'H': 7}
# C inf NIL {'H': 1}
# D inf NIL {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
# E inf NIL {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# F inf NIL {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# G inf NIL {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# H inf NIL {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J inf NIL {'D': 7, 'H': 1}

# %%
def relax(min_node):  ## u == src, v == dest in adjacent nodes, w == edge weight of u~v
    adj_node_names = list(min_node.edge_dict)
    
    ## for each vertext in G.Adj[u] implementation
    adj_node_list = []
    for adj_node_name in adj_node_names:
        for i in range(1, len(q.arr)):
            if adj_node_name == q.arr[i].vertex_name:
                adj_node_list.append(q.arr[i])
        
    for adj_node in adj_node_list:
    ## actual relaxation process
        if adj_node.min_dist > min_node.min_dist + min_node.edge_dict[adj_node.vertex_name]:
            adj_node.min_dist = min_node.min_dist + min_node.edge_dict[adj_node.vertex_name]
            adj_node.pred = min_node
    
    ## after relaxation, we need to keep min priority que property
    q.return_build_min_heap()

# %%
s = set() ## set for the processed graph node

for n in range(1, len(q.arr)):
    min_node = q.return_min_heap_extract()
    print("\n\n\n## min_node:", min_node.vertex_name, min_node)
    s = s | {min_node}
    print("\n#### before relax:"); print_graph(q.arr)
    relax(min_node)
    print("\n#### print set:"); print_graph(s)
    print("\n#### after relax:"); print_graph(q.arr)
# Out:
# ## min_node: A <__main__.Graph_node object at 0x0000021BA9E2AE90>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# J inf NIL {'D': 7, 'H': 1}
# B inf NIL {'A': 2, 'E': 5, 'H': 7}
# C inf NIL {'H': 1}
# D inf NIL {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
# E inf NIL {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# F inf NIL {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# G inf NIL {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# H inf NIL {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J inf NIL {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E2AE90>}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
# J 7 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'D': 7, 'H': 1}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# B inf NIL {'A': 2, 'E': 5, 'H': 7}
# E inf NIL {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# C inf NIL {'H': 1}
# G 6 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# H inf NIL {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 7 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'D': 7, 'H': 1}
#
#
#
# ## min_node: D <__main__.Graph_node object at 0x0000021BA9E40AF0>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# J 7 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'D': 7, 'H': 1}
# G 6 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# B inf NIL {'A': 2, 'E': 5, 'H': 7}
# E inf NIL {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# C inf NIL {'H': 1}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H inf NIL {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 7 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E40AF0>}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# G 6 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# B 10 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# C inf NIL {'H': 1}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 10 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
#
#
# ## min_node: F <__main__.Graph_node object at 0x0000021BA9E40BE0>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 6 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# B 10 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 2, 'E': 5, 'H': 7}
# H 10 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# C inf NIL {'H': 1}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 10 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I inf NIL {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# B 10 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 2, 'E': 5, 'H': 7}
# H 9 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 9 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
#
#
# ## min_node: C <__main__.Graph_node object at 0x0000021BA9E42CB0>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 10 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 2, 'E': 5, 'H': 7}
# H 9 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 9 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 10 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
#
#
# ## min_node: E <__main__.Graph_node object at 0x0000021BA9E42830>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 10 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
#
#
# ## min_node: G <__main__.Graph_node object at 0x0000021BA9E41EA0>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
#
#
# ## min_node: H <__main__.Graph_node object at 0x0000021BA9E41ED0>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
#
#
# ## min_node: B <__main__.Graph_node object at 0x0000021BA9E42B30>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
#
#
# ## min_node: I <__main__.Graph_node object at 0x0000021BA9E43FD0>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E40BE0>}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
#
#
# ## min_node: J <__main__.Graph_node object at 0x0000021BA9E43EB0>
#
# #### before relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
#
# #### print set:
# {<__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E40BE0>}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
#
# #### after relax:
# ['X', <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}

# %%
print_graph(s)
# Out:
# {<__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E40BE0>}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}

# %%
l = sorted(list(s), key = lambda x: x.vertex_name)

print_graph(l)
# Out:
# [<__main__.Graph_node object at 0x0000021BA9E2AE90>, <__main__.Graph_node object at 0x0000021BA9E42B30>, <__main__.Graph_node object at 0x0000021BA9E42CB0>, <__main__.Graph_node object at 0x0000021BA9E40AF0>, <__main__.Graph_node object at 0x0000021BA9E42830>, <__main__.Graph_node object at 0x0000021BA9E40BE0>, <__main__.Graph_node object at 0x0000021BA9E41EA0>, <__main__.Graph_node object at 0x0000021BA9E41ED0>, <__main__.Graph_node object at 0x0000021BA9E43FD0>, <__main__.Graph_node object at 0x0000021BA9E43EB0>]
# A 0 NIL {'D': 3, 'F': 3, 'G': 6, 'J': 7}
# B 6 <__main__.Graph_node object at 0x0000021BA9E42830> {'A': 2, 'E': 5, 'H': 7}
# C 4 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'H': 1}
# D 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 5, 'B': 7, 'E': 2, 'F': 3, 'G': 7, 'H': 7, 'J': 3}
# E 5 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'A': 3, 'B': 1, 'C': 5, 'D': 6, 'F': 4, 'H': 7, 'I': 5, 'J': 6}
# F 3 <__main__.Graph_node object at 0x0000021BA9E2AE90> {'A': 6, 'C': 1, 'D': 2, 'E': 3, 'G': 2, 'H': 6, 'I': 5, 'J': 4}
# G 5 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'B': 1, 'C': 5, 'D': 5, 'E': 6, 'H': 5, 'I': 6}
# H 5 <__main__.Graph_node object at 0x0000021BA9E42CB0> {'B': 2, 'C': 6, 'D': 6, 'G': 3, 'I': 7}
# I 8 <__main__.Graph_node object at 0x0000021BA9E40BE0> {'A': 6, 'D': 6, 'F': 3, 'G': 4, 'H': 2, 'J': 5}
# J 6 <__main__.Graph_node object at 0x0000021BA9E40AF0> {'D': 7, 'H': 1}

# %%
l = sorted(list(s), key = lambda x: x.vertex_name)

for x in l:
    print(
        # x.vertex_name,
        x.min_dist
        # x.pred,
        # x.edge_dict
    )
# Out:
# 0
# 6
# 4
# 3
# 5
# 3
# 5
# 5
# 8
# 6
